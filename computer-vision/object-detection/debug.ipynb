# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img1 = cv2.imread('/Users/punjayawickramasinghe/Downloads/IMG_0383.jpg', 0)
plt.imshow(img1)

# %%
resized = cv2.resize(img1, (0,0), fx=0.3, fy=0.3) 
plt.imshow(resized)
